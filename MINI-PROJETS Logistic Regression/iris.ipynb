# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

data = pd.read_csv('IRIS.csv')

le_species = LabelEncoder()
classes = data.drop('species', axis='columns')
target = le_species.fit_transform(data['species'])

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', max_depth=2)
model.fit(classes, target)
print(model.score(classes, target))
#sepal_length,sepal_width,petal_length,petal_width,species
print(model.predict([['5.7', '3', '4.2', '1.2']]))

model2 = DecisionTreeClassifier(criterion='entropy', max_depth=3)
model2.fit(classes, target)
print(model2.score(classes, target))
#sepal_length,sepal_width,petal_length,petal_width,species
print(model2.predict([['5.7', '3', '4.2', '1.2']]))


import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize=(10, 6))
tree.plot_tree(model, filled=True, fontsize=8)
plt.show()

# Tracer le deuxième arbre  
plt.figure(figsize=(15, 8))  
tree.plot_tree(model2, filled=True, fontsize=8)
plt.show()
# Out:
# C:\Users\VivoBook\AppData\Local\Temp\ipykernel_14572\895413014.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 0.96
# [1]
# 0.9733333333333334
# [1]
# C:\Users\VivoBook\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\VivoBook\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
